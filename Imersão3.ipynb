# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados ['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados ['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados ['tempo'].value_counts().plot.pie()

# %% [markdown]
# Desafio 1

# %%
São feitos, normalmente, 1 controle para cada droga usada, como elas são repetidas em situações diferentes, é normal ter um controle maior.
# Out:
#   File "<ipython-input-83-571e52b7660e>", line 3
#     São feitos, normalmente, 1 controle para cada droga usada, como elas são repetidas em situações diferentes, é normal ter um controle maior.
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# Desafio 2

# %%
dados.tail()

# %% [markdown]
# Desafio 3

# %%
dados["tratamento"].value_counts(normalize = True)

# %% [markdown]
# Desafio 4

# %%
quantidade_drogas = len(dados['droga'].unique())
print(quantidade_drogas)

# %% [markdown]
# Desafio 5

# %%
dados.query ('tempo == 24')

# %% [markdown]
# Desafio 6

# %%
dados.columns =  dados.columns.str.replace("-","")
dados

# %%
import matplotlib.pyplot as plt
dados ['tempo'].value_counts().plot.pie(colors = ("#a3966f", "#bd5fc7", "#2a6a6b"))
plt.title ("Tempo")

# %%
dados ['tratamento'].value_counts().plot.bar(title = "Tratamentos das amostras", color = ['#549997', '#bf4d67'])

# %% [markdown]
# Desafio 8

# %% [markdown]
# *  Foram feitos muitos trabalhos com as mesmas drogas, vide a grande diferença com o controle.
# *   São dadas 2 tipos de doses de medicamentos.
# *   Cada cultura é verificada a cada 24h, normalmente o tempo necessário em que as células se proliferam para podermos notar alguma diferença.
# *   Cada gene responde de forma bem diferente a cada droga

# %%
mapa = {'droga': 'composto'}
dados.rename (columns=mapa, inplace = True)
dados

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure (figsize=(8,6))
ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'))
ax.set_title ('Top 5 compostos')
plt.show()

# %%
len(dados ['g0'].unique())

# %%
dados ['g0'].min()

# %%
dados ['g0'].max()

# %%
dados ['g0'].hist(bins = 100)

# %%
dados.loc[:,'g0':'g771'].describe()

# %%
dados.loc[:,'g0':'g771'].describe().T['mean'].hist(bins=50)

# %%
dados.loc[:,'c0':'c99'].describe().T['mean'].hist(bins=50)

# %%
sns.boxplot(x='g0', data=dados)

# %%
plt.figure (figsize=(8,10))
sns.boxplot(y='g-0', x='tratamento', data = dados)

# %% [markdown]
# 1.   Ordenar o gráfico countplot
# 2.   Melhorar o gráfico, fonte, etc
# 3. Plotar os histogramas com o seaborn
# 4. Estudar sobre as estatísticas retornadas no .describe
# 5. Refletir sobre a manipulação dos tamanhos das visualizações
# 6. Fazer outras análises com o boxplot e até com o histograma

# %% [markdown]
# Desafio 2.1 - Ordenar o gráfico countplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure (figsize=(8,6))
ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'), order = cod_compostos)
ax.set_title ('Top 5 compostos')
plt.show()

# %% [markdown]
# Desafio 2.2 - Melhorar o gráfico, fonte, etc

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure (figsize=(8,6))
ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'), order = cod_compostos, color = 'mediumorchid', hatch = '/')
plt.ylabel("Quantas x foi usado", fontsize=17)
plt.xlabel("Compostos usados", fontsize=17)
ax.set_title ('Top 5 compostos', fontsize = 20)
plt.show()

# %% [markdown]
# 2.3 - Plotar os histogramas com o seaborn

# %%
import seaborn as sns

# %%
plt.figure (figsize=(8,6))
sns.histplot(dados.g3, bins=50, kde=True)
plt.title("Dados de G3", fontsize = 17)
plt.ylabel("N° de experimentos feitos", fontsize=17)
plt.xlabel("Expressões gênicas", fontsize=17)

# %%
sns.histplot(data=dados.loc[:, 'g0':'g73'].describe().T['mean'], color = 'mediumorchid', kde=True)
plt.title("Média de g0 até g73", fontsize = 17)
plt.ylabel("N° de experimentos feitos", fontsize=17)
plt.xlabel("Expressões gênicas", fontsize=17)

# %% [markdown]
# 2.4 - Estudar sobre as estatísticas retornadas no .describe

# %% [markdown]
# count = total do conjunto
# mean = o valor médio
# std =  desvião padrão, indica o quanto os dados são uniformes
# min = o valor mínimo dado
# max = o valor máximo dado
# 25% = primeiro quartil
# 50% = mediana
# 75% = terceiro quartil

# %% [markdown]
# 2.5 - Refletir sobre a manipulação dos tamanhos das visualizações.

# %% [markdown]
# Os gráficos precisam estar em um bom tamanho, se não os dados ficam distorcidos, quando formos analizarmos, não vamos conseguir especificar ou diferencia-los.

# %% [markdown]
# 2.6 - Fazer outras análises com o boxplot e até com o histograma

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='g8', data=dados, color = 'mediumorchid')

# %%
plt.figure (figsize=(8,6))
sns.histplot(dados.g8, bins=50, kde=True, color = 'mediumorchid')
plt.title("Dados de G8", fontsize = 17)
plt.ylabel("N° de experimentos feitos", fontsize=17)
plt.xlabel("Expressões gênicas", fontsize=17)

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='g8', y='tratamento', data=dados, color = 'mediumorchid')

# %% [markdown]
# 2.7 - Resumo da aula
#
#
# *   Podemos fazer diversas formas de análises visuais dos dados.
# *   Plotagem de diversos gráficos e quais suas diferenças, alguns dados vão ser preferíveis usar um gráfico específico.
#
#
# *  Importante ter um bom ajuste da imagem do gráfico para não ocorrer erros durante a análise
#
# *  Como deixar os gráficos bonitinhos :)

# %%
dados.head()

# %%
pd.crosstab(dados['dose'], dados['tempo'])

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados ['tratamento'])

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados ['tratamento'], normalize = 'index')

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados ['tratamento'], values = dados['g-0'], aggfunc='mean')

# %%
import seaborn as sns

sns.scatterplot (x='g-0', y='g-3', data = dados)

# %%
dados[['g-0', 'g-3']]

# %%
sns.scatterplot (x='g-0', y='g-8', data = dados)

# %% [markdown]
# 3.1 - Criar tabelas de frequência com o pandas.groupby()
#
# 3.2 - Normalizar o crosstab pela coluna
#
# 3.3 - Explorar outros agregadores
#
# 3.4 - Explorar o melt
#
# 3.5 - Calcular e analizar a correlação entre os g e c
#
# 3.6 - Estudar o código que plota a matriz de correlação

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color':'red'})

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color':'red'}, col='tratamento', row='tempo')

# %%
dados.loc[:,'g-0':'g-771'].corr()

# %%
corr = dados.loc[:,'g-0':'g-50'].corr()

# %%
import numpy as np
import matplotlib.pyplot as plt


# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:,'c-0':'c-50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# 3.1 - Criar tabelas de frequência com o pandas.groupby()

# %%
dados.groupby(by=['dose', 'tempo'])['tratamento'].value_counts()

# %%
dados.groupby(by=['tempo'])['tratamento'].value_counts()

# %% [markdown]
# 3.2 - Normalizar o crosstab pela coluna

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados ['tratamento'], normalize = 'columns')

# %% [markdown]
# 3.3 - Explorar outros agregadores

# %%
pd.pivot_table(dados, index='tratamento', aggfunc='mean')

# %%
dados.agg({'tempo' : ['max', 'min'], 'dose' : ['min', 'max']})

# %% [markdown]
# 3.4 - Explorar o melt

# %%
pd.melt(dados, id_vars= ['tempo', 'dose'])

# %%
pd.melt(dados, id_vars= ['tratamento', 'dose'])

# %% [markdown]
# 3.5 - Calcular e analizar a correlação entre os g e c

# %%
g = pd.DataFrame(dados[dados['dose'] == 'D1'].loc[:,'g-0':'g-20'])
c = pd.DataFrame(dados[dados['dose'] == 'D1'].loc[:,'c-0':'c-20'])
gec = pd.concat([g, c], axis =1, join = 'inner')
gec = gec.corr()
gec_corr = g_c.loc['c-0':'c-20','g-0':'g-20']
gec_corr
# Out:
#            g-0       g-1       g-2  ...      g-18      g-19      g-20
# c-0  -0.623017  0.088438 -0.120350  ...  0.112343  0.215256  0.451062
# c-1  -0.634405  0.080976 -0.132486  ...  0.074919  0.170210  0.388725
# c-2  -0.647538  0.075728 -0.127077  ...  0.091147  0.184714  0.435836
# c-3  -0.610505  0.126183 -0.118838  ...  0.119921  0.197533  0.416075
# c-4  -0.609930  0.080492 -0.128943  ...  0.079127  0.158789  0.430631
# c-5  -0.636441  0.114101 -0.119217  ...  0.078648  0.178459  0.439632
# c-6  -0.687514  0.083976 -0.132027  ...  0.043948  0.162010  0.442318
# c-7  -0.611495  0.103107 -0.137253  ...  0.092528  0.184860  0.458418
# c-8  -0.652149  0.104522 -0.128815  ...  0.086552  0.179989  0.425481
# c-9  -0.650664  0.117683 -0.115849  ...  0.050152  0.131499  0.434085
# c-10 -0.635275  0.103414 -0.129204  ...  0.044731  0.174879  0.476240
# c-11 -0.639309  0.087603 -0.128480  ...  0.106703  0.183799  0.458950
# ...

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(gec_corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(gec_corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Uma boa parte dos genes e das células possuem relação

# %% [markdown]
# Resumo do que aprendeu:
# -  heatmap
# - correlacionar colunas diferentes dos dados
# - usar o normalize nas colunas
